# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("parking_data.csv")

# %%
data
# Out:
#    vehicle_number         vehicle_type  contact_number ticket_number  \
# 0          ABC123                  Car      9876543210      A1B2C3D4
# 1          DEF456                 Bike      1234567890      E5F6G7H8
# 2          GHI789                Truck      9999999999      I9J8K7L6
# 3          JKL012  Physically disabled      1111111111      M0N1O2P3
# 4          MNO345                  Car      2222222222      Q4R5S6T7
# 5          PQR678                 Bike      3333333333      U8V9W0X1
# 6          STU901                Truck      4444444444      Y2Z3A4B5
# 7          VWX234  Physically disabled      5555555555      C6D7E8F9
# 8          YZA567                  Car      6666666666      G0H1I2J3
# 9          BCD890                 Bike      7777777777      K4L5M6N7
# 10         EFG123                Truck      8888888888      O8P9Q0R1
# 11         HIJ456  Physically disabled      9999999999      S2T3U4V5
# 12  ts-40 bQ-1254                  Car      9999999999      9SVVGU9V
# 13         ABC123                  Car      9876543210      A1B2C3D4
# 14         DEF456                 Bike      1234567890      E5F6G7H8
# 15         GHI789                Truck      9999999999      I9J8K7L6
# 16         JKL012  Physically disabled      1111111111      M0N1O2P3
# 17         MNO345                  Car      2222222222      Q4R5S6T7
# 18         PQR678                 Bike      3333333333      U8V9W0X1
# 19         STU901                Truck      4444444444      Y2Z3A4B5
# 20         VWX234  Physically disabled      5555555555      C6D7E8F9
# 21         YZA567                  Car      6666666666      G0H1I2J3
# 22         BCD890                 Bike      7777777777      K4L5M6N7
# 23         EFG123                Truck      8888888888      O8P9Q0R1
# 24         HIJ456  Physically disabled      9999999999      S2T3U4V5
# 25  ts-40 bQ-1254                  Car      9849378390      1ZTRZ53W
# 26         ABC123                  Car      9876543210      A1B2C3D4
# 27         DEF456                 Bike      1234567890      E5F6G7H8
# 28         GHI789                Truck      9999999999      I9J8K7L6
# 29         JKL012  Physically disabled      1111111111      M0N1O2P3
# 30         MNO345                  Car      2222222222      Q4R5S6T7
# 31         PQR678                 Bike      3333333333      U8V9W0X1
# 32         STU901                Truck      4444444444      Y2Z3A4B5
# 33         VWX234  Physically disabled      5555555555      C6D7E8F9
# 34         YZA567                  Car      6666666666      G0H1I2J3
# 35         BCD890                 Bike      7777777777      K4L5M6N7
# 36         EFG123                Truck      8888888888      O8P9Q0R1
# 37         HIJ456  Physically disabled      9999999999      S2T3U4V5
#
#         entry_time       exit_time  total_cost
# 0    1/1/2022 9:00  1/1/2022 10:30        15.0
# 1   1/1/2022 10:00  1/1/2022 11:30        10.0
# 2   1/1/2022 11:00  1/1/2022 13:30        30.0
# 3   1/1/2022 12:00  1/1/2022 14:30        20.0
# 4   1/1/2022 13:00  1/1/2022 15:30        20.0
# 5   1/1/2022 14:00  1/1/2022 16:30        15.0
# 6   1/1/2022 15:00  1/1/2022 18:30        45.0
# 7   1/1/2022 16:00  1/1/2022 19:30        30.0
# 8   1/1/2022 17:00  1/1/2022 20:30        30.0
# 9   1/1/2022 18:00  1/1/2022 21:30        25.0
# 10  1/1/2022 19:00  1/1/2022 23:30        60.0
# 11  1/1/2022 20:00   1/2/2022 1:30        45.0
# 12  1/1/2022 14:00  1/1/2022 15:00         NaN
# 13   1/1/2022 9:00  1/1/2022 10:30        15.0
# 14  1/1/2022 10:00  1/1/2022 11:30        10.0
# 15  1/1/2022 11:00  1/1/2022 13:30        30.0
# 16  1/1/2022 12:00  1/1/2022 14:30        20.0
# 17  1/1/2022 13:00  1/1/2022 15:30        20.0
# 18  1/1/2022 14:00  1/1/2022 16:30        15.0
# 19  1/1/2022 15:00  1/1/2022 18:30        45.0
# 20  1/1/2022 16:00  1/1/2022 19:30        30.0
# 21  1/1/2022 17:00  1/1/2022 20:30        30.0
# 22  1/1/2022 18:00  1/1/2022 21:30        25.0
# 23  1/1/2022 19:00  1/1/2022 23:30        60.0
# 24  1/1/2022 20:00   1/2/2022 1:30        45.0
# 25  1/1/2022 14:00  1/1/2022 15:00         NaN
# 26   1/1/2022 9:00  1/1/2022 10:30        15.0
# 27  1/1/2022 10:00  1/1/2022 11:30        10.0
# 28  1/1/2022 11:00  1/1/2022 13:30        30.0
# 29  1/1/2022 12:00  1/1/2022 14:30        20.0
# 30  1/1/2022 13:00  1/1/2022 15:30        20.0
# 31  1/1/2022 14:00  1/1/2022 16:30        15.0
# 32  1/1/2022 15:00  1/1/2022 18:30        45.0
# 33  1/1/2022 16:00  1/1/2022 19:30        30.0
# 34  1/1/2022 17:00  1/1/2022 20:30        30.0
# 35  1/1/2022 18:00  1/1/2022 21:30        25.0
# 36  1/1/2022 19:00  1/1/2022 23:30        60.0
# 37  1/1/2022 20:00   1/2/2022 1:30        45.0

# %%
sns.pairplot(data)

# %%
data.shape
# Out:
# (38, 7)

# %%
print('features of data set :',data.columns)
# Out:
# features of data set : Index(['vehicle_number', 'vehicle_type', 'contact_number', 'ticket_number',
#        'entry_time', 'exit_time', 'total_cost'],
#       dtype='object')

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25    False
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# dtype: bool

# %%
data.isnull().sum()
# Out:
# vehicle_number    0
# vehicle_type      0
# contact_number    0
# ticket_number     0
# entry_time        0
# exit_time         0
# total_cost        2
# dtype: int64

# %%
data = data.dropna()

# %%
data
# Out:
#    vehicle_number         vehicle_type  contact_number ticket_number  \
# 0          ABC123                  Car      9876543210      A1B2C3D4
# 1          DEF456                 Bike      1234567890      E5F6G7H8
# 2          GHI789                Truck      9999999999      I9J8K7L6
# 3          JKL012  Physically disabled      1111111111      M0N1O2P3
# 4          MNO345                  Car      2222222222      Q4R5S6T7
# 5          PQR678                 Bike      3333333333      U8V9W0X1
# 6          STU901                Truck      4444444444      Y2Z3A4B5
# 7          VWX234  Physically disabled      5555555555      C6D7E8F9
# 8          YZA567                  Car      6666666666      G0H1I2J3
# 9          BCD890                 Bike      7777777777      K4L5M6N7
# 10         EFG123                Truck      8888888888      O8P9Q0R1
# 11         HIJ456  Physically disabled      9999999999      S2T3U4V5
# 13         ABC123                  Car      9876543210      A1B2C3D4
# 14         DEF456                 Bike      1234567890      E5F6G7H8
# 15         GHI789                Truck      9999999999      I9J8K7L6
# 16         JKL012  Physically disabled      1111111111      M0N1O2P3
# 17         MNO345                  Car      2222222222      Q4R5S6T7
# 18         PQR678                 Bike      3333333333      U8V9W0X1
# 19         STU901                Truck      4444444444      Y2Z3A4B5
# 20         VWX234  Physically disabled      5555555555      C6D7E8F9
# 21         YZA567                  Car      6666666666      G0H1I2J3
# 22         BCD890                 Bike      7777777777      K4L5M6N7
# 23         EFG123                Truck      8888888888      O8P9Q0R1
# 24         HIJ456  Physically disabled      9999999999      S2T3U4V5
# 26         ABC123                  Car      9876543210      A1B2C3D4
# 27         DEF456                 Bike      1234567890      E5F6G7H8
# 28         GHI789                Truck      9999999999      I9J8K7L6
# 29         JKL012  Physically disabled      1111111111      M0N1O2P3
# 30         MNO345                  Car      2222222222      Q4R5S6T7
# 31         PQR678                 Bike      3333333333      U8V9W0X1
# 32         STU901                Truck      4444444444      Y2Z3A4B5
# 33         VWX234  Physically disabled      5555555555      C6D7E8F9
# 34         YZA567                  Car      6666666666      G0H1I2J3
# 35         BCD890                 Bike      7777777777      K4L5M6N7
# 36         EFG123                Truck      8888888888      O8P9Q0R1
# 37         HIJ456  Physically disabled      9999999999      S2T3U4V5
#
#         entry_time       exit_time  total_cost
# 0    1/1/2022 9:00  1/1/2022 10:30        15.0
# 1   1/1/2022 10:00  1/1/2022 11:30        10.0
# 2   1/1/2022 11:00  1/1/2022 13:30        30.0
# 3   1/1/2022 12:00  1/1/2022 14:30        20.0
# 4   1/1/2022 13:00  1/1/2022 15:30        20.0
# 5   1/1/2022 14:00  1/1/2022 16:30        15.0
# 6   1/1/2022 15:00  1/1/2022 18:30        45.0
# 7   1/1/2022 16:00  1/1/2022 19:30        30.0
# 8   1/1/2022 17:00  1/1/2022 20:30        30.0
# 9   1/1/2022 18:00  1/1/2022 21:30        25.0
# 10  1/1/2022 19:00  1/1/2022 23:30        60.0
# 11  1/1/2022 20:00   1/2/2022 1:30        45.0
# 13   1/1/2022 9:00  1/1/2022 10:30        15.0
# 14  1/1/2022 10:00  1/1/2022 11:30        10.0
# 15  1/1/2022 11:00  1/1/2022 13:30        30.0
# 16  1/1/2022 12:00  1/1/2022 14:30        20.0
# 17  1/1/2022 13:00  1/1/2022 15:30        20.0
# 18  1/1/2022 14:00  1/1/2022 16:30        15.0
# 19  1/1/2022 15:00  1/1/2022 18:30        45.0
# 20  1/1/2022 16:00  1/1/2022 19:30        30.0
# 21  1/1/2022 17:00  1/1/2022 20:30        30.0
# 22  1/1/2022 18:00  1/1/2022 21:30        25.0
# 23  1/1/2022 19:00  1/1/2022 23:30        60.0
# 24  1/1/2022 20:00   1/2/2022 1:30        45.0
# 26   1/1/2022 9:00  1/1/2022 10:30        15.0
# 27  1/1/2022 10:00  1/1/2022 11:30        10.0
# 28  1/1/2022 11:00  1/1/2022 13:30        30.0
# 29  1/1/2022 12:00  1/1/2022 14:30        20.0
# 30  1/1/2022 13:00  1/1/2022 15:30        20.0
# 31  1/1/2022 14:00  1/1/2022 16:30        15.0
# 32  1/1/2022 15:00  1/1/2022 18:30        45.0
# 33  1/1/2022 16:00  1/1/2022 19:30        30.0
# 34  1/1/2022 17:00  1/1/2022 20:30        30.0
# 35  1/1/2022 18:00  1/1/2022 21:30        25.0
# 36  1/1/2022 19:00  1/1/2022 23:30        60.0
# 37  1/1/2022 20:00   1/2/2022 1:30        45.0

# %%
data.dtypes
# Out:
# vehicle_number     object
# vehicle_type       object
# contact_number      int64
# ticket_number      object
# entry_time         object
# exit_time          object
# total_cost        float64
# dtype: object

# %%
data.head(10)
# Out:
#   vehicle_number         vehicle_type  contact_number ticket_number  \
# 0         ABC123                  Car      9876543210      A1B2C3D4
# 1         DEF456                 Bike      1234567890      E5F6G7H8
# 2         GHI789                Truck      9999999999      I9J8K7L6
# 3         JKL012  Physically disabled      1111111111      M0N1O2P3
# 4         MNO345                  Car      2222222222      Q4R5S6T7
# 5         PQR678                 Bike      3333333333      U8V9W0X1
# 6         STU901                Truck      4444444444      Y2Z3A4B5
# 7         VWX234  Physically disabled      5555555555      C6D7E8F9
# 8         YZA567                  Car      6666666666      G0H1I2J3
# 9         BCD890                 Bike      7777777777      K4L5M6N7
#
#        entry_time       exit_time  total_cost
# 0   1/1/2022 9:00  1/1/2022 10:30        15.0
# 1  1/1/2022 10:00  1/1/2022 11:30        10.0
# 2  1/1/2022 11:00  1/1/2022 13:30        30.0
# 3  1/1/2022 12:00  1/1/2022 14:30        20.0
# 4  1/1/2022 13:00  1/1/2022 15:30        20.0
# 5  1/1/2022 14:00  1/1/2022 16:30        15.0
# 6  1/1/2022 15:00  1/1/2022 18:30        45.0
# 7  1/1/2022 16:00  1/1/2022 19:30        30.0
# 8  1/1/2022 17:00  1/1/2022 20:30        30.0
# 9  1/1/2022 18:00  1/1/2022 21:30        25.0

# %%
data.tail(10)
# Out:
#    vehicle_number         vehicle_type  contact_number ticket_number  \
# 28         GHI789                Truck      9999999999      I9J8K7L6
# 29         JKL012  Physically disabled      1111111111      M0N1O2P3
# 30         MNO345                  Car      2222222222      Q4R5S6T7
# 31         PQR678                 Bike      3333333333      U8V9W0X1
# 32         STU901                Truck      4444444444      Y2Z3A4B5
# 33         VWX234  Physically disabled      5555555555      C6D7E8F9
# 34         YZA567                  Car      6666666666      G0H1I2J3
# 35         BCD890                 Bike      7777777777      K4L5M6N7
# 36         EFG123                Truck      8888888888      O8P9Q0R1
# 37         HIJ456  Physically disabled      9999999999      S2T3U4V5
#
#         entry_time       exit_time  total_cost
# 28  1/1/2022 11:00  1/1/2022 13:30        30.0
# 29  1/1/2022 12:00  1/1/2022 14:30        20.0
# 30  1/1/2022 13:00  1/1/2022 15:30        20.0
# 31  1/1/2022 14:00  1/1/2022 16:30        15.0
# 32  1/1/2022 15:00  1/1/2022 18:30        45.0
# 33  1/1/2022 16:00  1/1/2022 19:30        30.0
# 34  1/1/2022 17:00  1/1/2022 20:30        30.0
# 35  1/1/2022 18:00  1/1/2022 21:30        25.0
# 36  1/1/2022 19:00  1/1/2022 23:30        60.0
# 37  1/1/2022 20:00   1/2/2022 1:30        45.0

# %%
data.value_counts()
# Out:
# vehicle_number  vehicle_type         contact_number  ticket_number  entry_time      exit_time       total_cost
# ABC123          Car                  9876543210      A1B2C3D4       1/1/2022 9:00   1/1/2022 10:30  15.0          3
# BCD890          Bike                 7777777777      K4L5M6N7       1/1/2022 18:00  1/1/2022 21:30  25.0          3
# DEF456          Bike                 1234567890      E5F6G7H8       1/1/2022 10:00  1/1/2022 11:30  10.0          3
# EFG123          Truck                8888888888      O8P9Q0R1       1/1/2022 19:00  1/1/2022 23:30  60.0          3
# GHI789          Truck                9999999999      I9J8K7L6       1/1/2022 11:00  1/1/2022 13:30  30.0          3
# HIJ456          Physically disabled  9999999999      S2T3U4V5       1/1/2022 20:00  1/2/2022 1:30   45.0          3
# JKL012          Physically disabled  1111111111      M0N1O2P3       1/1/2022 12:00  1/1/2022 14:30  20.0          3
# MNO345          Car                  2222222222      Q4R5S6T7       1/1/2022 13:00  1/1/2022 15:30  20.0          3
# PQR678          Bike                 3333333333      U8V9W0X1       1/1/2022 14:00  1/1/2022 16:30  15.0          3
# STU901          Truck                4444444444      Y2Z3A4B5       1/1/2022 15:00  1/1/2022 18:30  45.0          3
# VWX234          Physically disabled  5555555555      C6D7E8F9       1/1/2022 16:00  1/1/2022 19:30  30.0          3
# YZA567          Car                  6666666666      G0H1I2J3       1/1/2022 17:00  1/1/2022 20:30  30.0          3
# dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
#pie chart to analysis to vehical types
data['vehicle_type'].value_counts().plot.pie(explode=[0.01,0.01,0.01,0.01],startangle=90,shadow=True,figsize=(8,8))
plt.title('pie chart for vehicle_type')
plt.show()

# %%
#histogram for total cost
data['total_cost'].hist()
# Out:
# <AxesSubplot:>

# %%
data['vehicle_type'].hist()
# Out:
# <AxesSubplot:>
